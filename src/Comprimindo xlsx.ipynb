# %%
import pandas as pd
import numpy as np

# %%
test = pd.DataFrame(data=["daniel"], index=False)

# %%
test.to_excel("test.xlsx")

# %%
df = pd.read_excel("escolas_sort.xlsx")

# %%
df.replace(np.nan, "null", inplace=True)

# %%
states = df["Estado"].unique().tolist()

# %%
for state in states:
    new_df = df[df["Estado"] == state]
    new_df.to_excel("../Estados/"+state+".xlsx", index=False)

# %%
df[df["Cidade"] == "Niterói"]
# Out:
#        Estado   Cidade            Bairro  \
# 288376     RJ  Niterói            Centro
# 288380     RJ  Niterói            Centro
# 288388     RJ  Niterói            Centro
# 288389     RJ  Niterói            Icarai
# 288390     RJ  Niterói              Inga
# 288394     RJ  Niterói            Itaipu
# 288395     RJ  Niterói           Niteroi
# 288396     RJ  Niterói        Santa Rosa
# 288399     RJ  Niterói           Fonseca
# 288401     RJ  Niterói     Sao Francisco
# 288402     RJ  Niterói           Barreto
# 288403     RJ  Niterói       Piratininga
# 288404     RJ  Niterói            Icarai
# 288406     RJ  Niterói          Charitas
# 288411     RJ  Niterói      Ponta Dareia
# 288412     RJ  Niterói           Barreto
# 288414     RJ  Niterói           Barreto
# 288415     RJ  Niterói      Ponta Dareia
# 288416     RJ  Niterói           Fonseca
# 288417     RJ  Niterói            Itaipu
# 288418     RJ  Niterói         Engenhoca
# 288419     RJ  Niterói           Fonseca
# ...
